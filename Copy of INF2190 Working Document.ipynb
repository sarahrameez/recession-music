# %% [markdown]
# # Popular Music in Recession Years

# %% [markdown]
# ## Cleaning the Data Sets

# %%
from google.colab import drive
drive.mount('/drive', force_remount=True)

# %cd '/drive/MyDrive/Colab Notebooks/INF2190/INF2190 Final Project/'
# Out:
# Mounted at /drive
# /drive/MyDrive/Colab Notebooks/INF2190/INF2190 Final Project

# %% [markdown]
# ### Cleaning BillBoard Hot 100

# %%
#Import pandas and read the Billboard 100 dataframe
import pandas as pd
hot100 = pd.read_csv('data/hot-100-current.csv')


#Convert characters in the dataframe to lowercase
hot100['title'] = hot100['title'].str.lower()
hot100['performer'] = hot100['performer'].str.lower()


#Check for null values, replace found null values with 'NA'
hot100.info()
hot100 = hot100.fillna('NA')

#Create function for removing punctuation
def remove_punctuation (df):
  if isinstance(text, str):
    return text.translate(str.maketrans('', '', string.punctuation))
  return text

#Remove punctuation


#Converting chart_week to date format and create a new column for year
hot100['Year'] = pd.to_datetime(hot100['chart_week'])
hot100['Year'] = hot100['Year'].dt.year
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343600 entries, 0 to 343599
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   chart_week    343600 non-null  object
#  1   current_week  343600 non-null  int64
#  2   title         343600 non-null  object
#  3   performer     343600 non-null  object
#  4   last_week     311140 non-null  float64
#  5   peak_pos      343600 non-null  int64
#  6   wks_on_chart  343600 non-null  int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 18.4+ MB

# %% [markdown]
# ### Cleaning the US Recession

# %%
# opening the csv file

recession_all_years = pd.read_csv('data/USREC.csv')

recession_all_years.head()
# Out:
#          DATE  USREC
# 0  1854-12-01      1
# 1  1855-01-01      0
# 2  1855-02-01      0
# 3  1855-03-01      0
# 4  1855-04-01      0

# %%
# gain information and check for missing values
def retrievinginfo(dataFrame):
  # retrieving general info
  print("Basic information about the dataset: ", '\n', dataFrame.info())
  # checking for missing values
  missingValue = dataFrame.isnull().sum()
  print("The Number of missing values in the dataset are: ", missingValue)


# clean to date time
def cleaning_date(dataFrame,column_name, new_column):
  dataFrame[column_name] = pd.to_datetime(dataFrame[column_name], errors='coerce')
  # extract the year from date column to create year column
  dataFrame[new_column] = dataFrame[column_name].dt.year

# Creating new data frame filtering out the years that are not in the range of 1990-2024
def createFrame(dataFrame, filter_column):
  newDataFrame = dataFrame[(dataFrame[filter_column] >= 1990) & (dataFrame[filter_column] <= 2024)]
  return newDataFrame

# function to rename column names to standardize and make more clear
def rename_columns(dataFrame, column_names):
  return dataFrame.rename(columns=column_names, inplace=False)


# execute the functions
column_new_names = {'DATE':'recession date','USREC':'recession'} # created data frame to store changes in column titles
retrievinginfo(recession_all_years)
cleaning_date(recession_all_years, 'DATE', 'Year')

# saving the filtered clean version to new dataframe
recession_years = createFrame(recession_all_years, 'Year')
recession_years = rename_columns(recession_years, column_new_names)

# verify it is clean
print(recession_years.head())
recession_years.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2039 entries, 0 to 2038
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    2039 non-null   object
#  1   USREC   2039 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 32.0+ KB
# Basic information about the dataset:
#  None
# The Number of missing values in the dataset are:  DATE     0
# USREC    0
# dtype: int64
#      recession date  recession  Year
# 1621     1990-01-01          0  1990
# 1622     1990-02-01          0  1990
# 1623     1990-03-01          0  1990
# 1624     1990-04-01          0  1990
# 1625     1990-05-01          0  1990
# <class 'pandas.core.frame.DataFrame'>
# Index: 418 entries, 1621 to 2038
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   recession date  418 non-null    datetime64[ns]
#  1   recession       418 non-null    int64
#  2   Year            418 non-null    int32
# dtypes: datetime64[ns](1), int32(1), int64(1)
# memory usage: 11.4 KB

# %% [markdown]
# ### Merging the Data sets

# %%
# merging the year and recession columns to the billboard hot 100 based on year
recession_music = hot100.merge(recession_years[['Year', 'recession']], on='Year', how='inner')

# should discuss with everyone if we are dropping the year and date column


# save the new merged data frame to a csv file (so later it will be easy to open and join with the spotify)

recession_music.to_csv('recession_music.csv', index=False)

# %%
recession_music.head()
# Out:
#    chart_week  current_week                            title     performer  \
# 0  2022-01-01             1  all i want for christmas is you  mariah carey
# 1  2022-01-01             1  all i want for christmas is you  mariah carey
# 2  2022-01-01             1  all i want for christmas is you  mariah carey
# 3  2022-01-01             1  all i want for christmas is you  mariah carey
# 4  2022-01-01             1  all i want for christmas is you  mariah carey
#
#   last_week  peak_pos  wks_on_chart  Year  recession
# 0       1.0         1            50  2022          0
# 1       1.0         1            50  2022          0
# 2       1.0         1            50  2022          0
# 3       1.0         1            50  2022          0
# 4       1.0         1            50  2022          0

# %% [markdown]
# ## Descriptive Analysis

# %%
##### Visualize songs that are in years of recessions


##### Visualize songs that are in years of non-recession

# %%
##### look at beats per minute mean in years of recession

#### look at beats per minute mean in years of non-recession

# %%
#### look at mode track release date for during periods of recession vs non-recession/ prportion of tracks not from year of chart

# %%
#### look at the mean dancability score (all years, then for years of recession vs years or non-recession)

# %%
##### look at mean song length in years of recession


#### look at mean song length in years of non-recession

# %%
##### Song titles text analysis

### using nltk , TF, and TFIDF to look at frequent words in song titles (for all years, then for years of recession vs years of non recession)

# %%
##### song lyrics text analysis

# sentiment analysis using nltk on the lyrics , assigning a score to the common words
# it includes TF and IDF in the nltk library through s k learn (look up if confused, and also in the data analytics slides)

# function that counts the frequency of words within the lyrics and looks at average frequency count in recession years vs non recession
    # ratio of unique words to repeat words ...the higher the ratio the more repetive the song

# %% [markdown]
# ## Diagnostic Analysis
